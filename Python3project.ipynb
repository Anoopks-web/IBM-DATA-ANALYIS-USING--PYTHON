# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import Normalize

# %%
df=pd.read_csv("/content/hr.csv")

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 1470
# Columns: 35

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
missing_percentage = (
    df.isnull().sum() / len(df)
) * 100

print(
    missing_percentage
    .sort_values(ascending=False)
)
# Out:
# Age                         0.0
# Attrition                   0.0
# BusinessTravel              0.0
# DailyRate                   0.0
# Department                  0.0
# DistanceFromHome            0.0
# Education                   0.0
# EducationField              0.0
# EmployeeCount               0.0
# EmployeeNumber              0.0
# EnvironmentSatisfaction     0.0
# Gender                      0.0
# HourlyRate                  0.0
# JobInvolvement              0.0
# JobLevel                    0.0
# JobRole                     0.0
# JobSatisfaction             0.0
# MaritalStatus               0.0
# MonthlyIncome               0.0
# MonthlyRate                 0.0
# NumCompaniesWorked          0.0
# Over18                      0.0
# OverTime                    0.0
# PercentSalaryHike           0.0
# PerformanceRating           0.0
# RelationshipSatisfaction    0.0
# StandardHours               0.0
# StockOptionLevel            0.0
# TotalWorkingYears           0.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()
print("Shape after removing duplicates:", df.shape)
# Out:
# Shape after removing duplicates: (1470, 35)

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
print(df.nunique().sort_values())
# Out:
# EmployeeCount                  1
# Over18                         1
# StandardHours                  1
# Attrition                      2
# OverTime                       2
# PerformanceRating              2
# Gender                         2
# BusinessTravel                 3
# Department                     3
# MaritalStatus                  3
# RelationshipSatisfaction       4
# StockOptionLevel               4
# JobSatisfaction                4
# EnvironmentSatisfaction        4
# JobInvolvement                 4
# WorkLifeBalance                4
# Education                      5
# JobLevel                       5
# EducationField                 6
# TrainingTimesLastYear          7
# JobRole                        9
# NumCompaniesWorked            10
# PercentSalaryHike             15
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# YearsInCurrentRole            19
# DistanceFromHome              29
# YearsAtCompany                37
# ...

# %%
print("EmployeeCount:", df['EmployeeCount'].nunique())
print("StandardHours:", df['StandardHours'].nunique())
print("Over18:", df['Over18'].nunique())
# Out:
# EmployeeCount: 1
# StandardHours: 1
# Over18: 1

# %%
df = df.drop(columns=[
    'EmployeeNumber',
    'EmployeeCount',
    'StandardHours',
    'Over18'
])
print("Columns after dropping:", len(df.columns))
print("New Shape:", df.shape)
# Out:
# Columns after dropping: 31
# New Shape: (1470, 31)

# %%
categorical_column=df.select_dtypes(include='object').columns
for i in categorical_column:
  print(i)
  a=df[i].value_counts()
  print(a)
# Out:
# Attrition
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# BusinessTravel
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
# Department
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
# EducationField
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
# Gender
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64
# JobRole
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# ...

# %%
numericl_columns=df.select_dtypes(include='int64').columns
for  i in numericl_columns:
  print(i)
  print(df[i].value_counts())
# Out:
# Age
# Age
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 38    58
# 33    58
# 40    57
# 37    50
# 28    48
# 27    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 48    19
# 51    19
# 53    19
# 54    18
# 52    18
# 22    16
# 56    14
# 58    14
# 23    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: count, dtype: int64
# DailyRate
# DailyRate
# 691     6
# 1082    5
# 329     5
# 530     5
# 408     5
#        ..
# 1382    1
# 161     1
# 801     1
# 642     1
# 1154    1
# Name: count, Length: 886, dtype: int64
# DistanceFromHome
# DistanceFromHome
# 2     211
# 1     208
# 10     86
# 9      85
# 3      84
# 7      84
# 8      80
# 5      65
# 4      64
# 6      59
# 16     32
# 11     29
# 24     28
# 29     27
# 23     27
# 15     26
# 18     26
# 20     25
# 25     25
# 26     25
# 28     23
# ...

# %%
numerical_columns = df.select_dtypes(
    include=np.number
).columns

print(numerical_columns.tolist())
# Out:
# ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
df[numerical_columns].describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %%
for col in numericl_columns:
  negative_values=(df[col]<0).sum()
  if negative_values>0:
     print(col, ":", negative_values)

# %%
print(df['Attrition'].value_counts())
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
print(df['Age'].value_counts())
# Out:
# Age
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 38    58
# 33    58
# 40    57
# 37    50
# 28    48
# 27    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 48    19
# 51    19
# 53    19
# 54    18
# 52    18
# 22    16
# 56    14
# 58    14
# 23    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: count, dtype: int64

# %%
print(df['Department'].value_counts())
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
print(df['JobRole'].value_counts())
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
print(df['OverTime'].value_counts())
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
print(df['Education'].value_counts())
# Out:
# Education
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: count, dtype: int64

# %%
#Arrange age into groupage
df['Age Group']=pd.cut(df['Age'],bins=[0,25,35,45,55,100],labels=['Under 25','25-35','36-45','46-55','55+'])
df['Age Group']
# Out:
# 0       36-45
# 1       46-55
# 2       36-45
# 3       25-35
# 4       25-35
#         ...
# 1465    36-45
# 1466    36-45
# 1467    25-35
# 1468    46-55
# 1469    25-35
# Name: Age Group, Length: 1470, dtype: category
# Categories (5, object): ['Under 25' < '25-35' < '36-45' < '46-55' < '55+']

# %%
df['Age Group'].value_counts()
# Out:
# Age Group
# 25-35       606
# 36-45       468
# 46-55       226
# Under 25    123
# 55+          47
# Name: count, dtype: int64

# %%
df['Income Group']=pd.cut(df['MonthlyIncome'],bins=[0, 3000, 6000, 10000, 15000, np.inf],
    labels=[
        'Low',
        'Medium',
        'High',
        'Very High',
        'Extremely High'
    ]
)
df['Income Group']
# Out:
# 0       Medium
# 1       Medium
# 2          Low
# 3          Low
# 4       Medium
#          ...
# 1465       Low
# 1466      High
# 1467      High
# 1468    Medium
# 1469    Medium
# Name: Income Group, Length: 1470, dtype: category
# Categories (5, object): ['Low' < 'Medium' < 'High' < 'Very High' < 'Extremely High']

# %%
df['Income Group'].value_counts()
# Out:
# Income Group
# Medium            519
# Low               395
# High              275
# Very High         148
# Extremely High    133
# Name: count, dtype: int64

# %%
df['Experience_Group'] = pd.cut(
    df['TotalWorkingYears'],
    bins=[-1, 2, 5, 10, 20, np.inf],
    labels=[
        '0-2 Years',
        '3-5 Years',
        '6-10 Years',
        '11-20 Years',
        '20+ Years'
    ]
)
df['Experience_Group']
# Out:
# 0        6-10 Years
# 1        6-10 Years
# 2        6-10 Years
# 3        6-10 Years
# 4        6-10 Years
#            ...
# 1465    11-20 Years
# 1466     6-10 Years
# 1467     6-10 Years
# 1468    11-20 Years
# 1469     6-10 Years
# Name: Experience_Group, Length: 1470, dtype: category
# Categories (5, object): ['0-2 Years' < '3-5 Years' < '6-10 Years' < '11-20 Years' < '20+ Years']

# %%
df['Experience_Group'].value_counts()
# Out:
# Experience_Group
# 6-10 Years     607
# 11-20 Years    340
# 20+ Years      207
# 3-5 Years      193
# 0-2 Years      123
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1470, 34)

# %%
print("\nMissing Values:")
print(df.isnull().sum().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Missing Values:
# 0
#
# Duplicate Rows:
# 0

# %%
df.to_csv(
    "/content/IBM_HR_Analytics_Cleaned.csv",
    index=False
)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
df=pd.read_csv("/content/IBM_HR_Analytics_Cleaned.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %%
df.shape
# Out:
# (1470, 34)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Age Group',
#        'Income Group', 'Experience_Group'],
#       dtype='object')

# %%
# How many employees are in the dataset?
print(len(df))
# Out:
# 1470

# %%
# How many columns are present?
print(len(df.columns))
# Out:
# 34

# %%
# What are the column names?
print(df.columns.tolist())
# Out:
# ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Age Group', 'Income Group', 'Experience_Group']

# %%
# What are the data types of each column?
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# ...

# %%
# Are there any missing values?
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# Are there any duplicate records?
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# What is the average employee age?
avg_age=df['Age'].mean()
print('avg_age:',avg_age)
# Out:
# avg_age: 36.923809523809524

# %%
# What is the minimum employee age?
min_age=df['Age'].min()
print('the mininum age is:',min_age)
# Out:
# the mininum age is: 18

# %%
# What is the maximum employee age?
max_age=df['Age'].max()
print('max_age:',max_age)
# Out:
# max_age: 60

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Age Group',
#        'Income Group', 'Experience_Group'],
#       dtype='object')

# %%
# What is the average monthly income?
avg_monthly_income=df['MonthlyIncome'].mean()
print(avg_monthly_income)
# Out:
# 6502.931292517007

# %%
# What is the minimum monthly income?
min_monthlyincome=df['MonthlyIncome'].min()
print(min_monthlyincome)
# Out:
# 1009

# %%
# What is the maximum monthly income?
max_monthlyincome=df['MonthlyIncome'].max()
print(max_monthlyincome)
# Out:
# 19999

# %%
# What  the average total working experience?
avg_experince=df['TotalWorkingYears'].mean()
print(avg_experince)
# Out:
# 11.279591836734694

# %%
# How many unique job roles are there?
uniquerole=df['JobRole'].nunique()
print(uniquerole)
# Out:
# 9

# %%
# How many unique departments are there?
print("Departments:", df['Department'].nunique())
# Out:
# Departments: 3

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Age Group',
#        'Income Group', 'Experience_Group'],
#       dtype='object')

# %% [markdown]
# Level 2 — Employee Analysis

# %%
# How many male and female employees are there?
df['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
# What percentage of employees are male and female?
print(df['Gender'].value_counts(normalize=True) * 100)
# Out:
# Gender
# Male      60.0
# Female    40.0
# Name: proportion, dtype: float64

# %%
# Which department has the highest number of employees?
employes=df['Department'].value_counts()
employes.sort_values(ascending=False).head(1)
# Out:
# Department
# Research & Development    961
# Name: count, dtype: int64

# %%
# Which department has the lowest number of eployees?
employes=df['Department'].value_counts().sort_index(ascending=False).tail(1)
print(employes)
# Out:
# Department
# Human Resources    63
# Name: count, dtype: int64

# %%
# Which job role has the highest number of employees?
job_roles = df['JobRole'].value_counts()
print("Job Role:", job_roles.idxmax())
print("Employees:", job_roles.max())
# Out:
# Job Role: Sales Executive
# Employees: 326

# %%
# Which job role has the lowest number of employees?
job_role_employee=df['JobRole'].value_counts()
lowestemployee=job_role_employee.sort_values(ascending=True).head(1)
lowestemployee
# Out:
# JobRole
# Human Resources    52
# Name: count, dtype: int64

# %%
# Which business travel category has te most employees?
df['BusinessTravel'].value_counts().sort_values(ascending=False).head(1)
# Out:
# BusinessTravel
# Travel_Rarely    1043
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Age Group',
#        'Income Group', 'Experience_Group'],
#       dtype='object')

# %%
# How many employees work overtime?
df['OverTime'].value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
# What percentage of employees work overtime?
print(df['OverTime'].value_counts(normalize=True) * 100)
# Out:
# OverTime
# No     71.70068
# Yes    28.29932
# Name: proportion, dtype: float64

# %%
# What is the average distance employees travel to work?
print(df['DistanceFromHome'].mean())
# Out:
# 9.19251700680272

# %%
# Which department has the highest average age?
df.groupby("Department")['Age'].mean().sort_index(ascending=False).head(1)
# Out:
# Department
# Sales    36.542601
# Name: Age, dtype: float64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Age Group',
#        'Income Group', 'Experience_Group'],
#       dtype='object')

# %%
# Which department has the highest average monthly income?
df.groupby("Department")['MonthlyIncome'].mean().sort_values(ascending=True).head(1)
# Out:
# Department
# Research & Development    6281.252862
# Name: MonthlyIncome, dtype: float64

# %%
# Which job role has the highest average monthly income?
df.groupby('JobRole')['MonthlyIncome'].mean().sort_values(ascending=False).head(1)
# Out:
# JobRole
# Manager    17181.676471
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# Attrition Analysis

# %%
# How many employees have left the company?
cmpy_left=(df['Attrition']=='Yes').sum()
print('left the number of employees left the cmpy:',cmpy_left)
# Out:
# left the number of employees left the cmpy: 237

# %%
# How many employees are still working?
still_on_job=(df['Attrition']=='No').sum()
print(still_on_job)
# Out:
# 1233

# %%
# What is the overall attrition rate?
attrition_rate = (df['Attrition'] == 'Yes').mean() * 100
print(f"Attrition Rate: {attrition_rate:.2f}%")
# Out:
# Attrition Rate: 16.12%

# %%
# What percentage of employees stayed?
stay_rate = (df['Attrition'] == 'No').mean() * 100
print(f"Stay Rate: {stay_rate:.2f}%")
# Out:
# Stay Rate: 83.88%

# %%
# Which department has the highest attrition rate?
print(
    pd.crosstab(
        df['Department'],
        df['Attrition'],
        normalize='index'
    ) * 100
)
# Out:
# Attrition                      No        Yes
# Department
# Human Resources         80.952381  19.047619
# Research & Development  86.160250  13.839750
# Sales                   79.372197  20.627803

# %%
# Which department has the lowest attrition rate?
dept_attrition = pd.crosstab(
    df['Department'],
    df['Attrition'],
    normalize='index'
) * 100

print(dept_attrition['Yes'].sort_values())
# Out:
# Department
# Research & Development    13.839750
# Human Resources           19.047619
# Sales                     20.627803
# Name: Yes, dtype: float64

# %%
# Which job role has the highest attrition rate?
jobrole_attrition=pd.crosstab(df['Department'],df['Attrition'],normalize='index')*100
jobrole_attrition
# Out:
# Attrition                      No        Yes
# Department
# Human Resources         80.952381  19.047619
# Research & Development  86.160250  13.839750
# Sales                   79.372197  20.627803

# %%
# Which job role has the lowest attrition rate?
jobrole_attrition=pd.crosstab(df['Department'],df['Attrition'],normalize='index')*100
jobrole_attrition.sort_values('Yes',ascending=True).tail(1)
# Out:
# Attrition          No        Yes
# Department
# Sales       79.372197  20.627803

# %%
# Does gender affect employee attrition?
print(
    pd.crosstab(
        df['Gender'],
        df['Attrition'],
        normalize='index'
    ) * 100
)
# Out:
# Attrition         No        Yes
# Gender
# Female     85.204082  14.795918
# Male       82.993197  17.006803

# %%
# Does marital status affect attrition?
print(
    pd.crosstab(
        df['BusinessTravel'],
        df['Attrition'],
        normalize='index'
    ) * 100
)
# Out:
# Attrition                 No        Yes
# BusinessTravel
# Non-Travel         92.000000   8.000000
# Travel_Frequently  75.090253  24.909747
# Travel_Rarely      85.043145  14.956855

# %%
# Does overtime affect attrition?

print(
    pd.crosstab(
        df['OverTime'],
        df['Attrition'],
        normalize='index'
    ) * 100
)
# Out:
# Attrition         No        Yes
# OverTime
# No         89.563567  10.436433
# Yes        69.471154  30.528846

# %%
# Does education level affect attrition?
print(
    pd.crosstab(
        df['EducationField'],df['Attrition'],
        normalize='index'
    ) *100
)
# Out:
# Attrition                No        Yes
# EducationField
# Human Resources   74.074074  25.925926
# Life Sciences     85.313531  14.686469
# Marketing         77.987421  22.012579
# Medical           86.422414  13.577586
# Other             86.585366  13.414634
# Technical Degree  75.757576  24.242424

# %%
# Does job level affect attrition?
print(pd.crosstab(df['JobLevel'],df['Attrition'],normalize='index')*100)
# Out:
# Attrition         No        Yes
# JobLevel
# 1          73.664825  26.335175
# 2          90.262172   9.737828
# 3          85.321101  14.678899
# 4          95.283019   4.716981
# 5          92.753623   7.246377

# %%
# Does distance from home affect attrition
print(pd.crosstab(df['DistanceFromHome'],df['Attrition'],normalize='index')*100)
# Out:
# Attrition                No        Yes
# DistanceFromHome
# 1                 87.500000  12.500000
# 2                 86.729858  13.270142
# 3                 83.333333  16.666667
# 4                 85.937500  14.062500
# 5                 84.615385  15.384615
# 6                 88.135593  11.864407
# 7                 86.904762  13.095238
# 8                 87.500000  12.500000
# 9                 78.823529  21.176471
# 10                87.209302  12.790698
# 11                86.206897  13.793103
# 12                70.000000  30.000000
# 13                68.421053  31.578947
# 14                80.952381  19.047619
# 15                80.769231  19.230769
# 16                78.125000  21.875000
# 17                75.000000  25.000000
# 18                84.615385  15.384615
# 19                86.363636  13.636364
# 20                84.000000  16.000000
# 21                83.333333  16.666667
# 22                68.421053  31.578947
# ...

# %% [markdown]
# Age & Income Analysis

# %%
# What is the average age of employees who left?
print(df[df['Attrition']=='Yes']['Age'].mean())

# %%
# What is the average age of employees who stayed?
print(df[df['Attrition']=='No']['Age'].mean())
# Out:
# 37.561232765612324

# %%
# Which age group has the highest attrition?
attrition_age_group = df[df['Attrition'] == 'Yes']['Age Group'].value_counts()
print({attrition_age_group.idxmax():attrition_age_group.max()})
# Out:
# {'25-35': 116}

# %%
# Which age group has the lowest attrition?
attrition_age_group = df[df['Attrition'] == 'Yes']['Age Group'].value_counts()
lowest_attrition=dict({attrition_age_group.idxmin():attrition_age_group.min()})
print(lowest_attrition)
# Out:
# {'55+': 8}

# %%
# What is the average income of employees who left?
avg_attrition_income =df[df['Attrition']=='Yes']['MonthlyIncome'].mean()
print(avg_attrition_income)
print(round(avg_attrition_income,2))
print({'Avg Attrition Income': float(round(avg_attrition_income, 2))})
# Out:
# 4787.0928270042195
# 4787.09
# {'Avg Attrition Income': 4787.09}

# %%
# What is the average income of employees who stayed?
avg_notattrition_income=df[df['Attrition']=='No']['MonthlyIncome'].mean()
print(avg_notattrition_income)
print(round(avg_notattrition_income,2))
print({'avg_notattrition_income':float(round(avg_notattrition_income,2))})
# Out:
# 6832.739659367397
# 6832.74
# {'avg_notattrition_income': 6832.74}

# %%
# Does higher monthly income reduce attrition?
avg_income=df.groupby("Attrition")['MonthlyIncome'].mean()
avg_income_attrition=("avg income attrited:",float(avg_income['Yes']))
print(avg_income_attrition)
avg_income_notattrited=("abg_income of not atrraited is:",float(avg_income['No']))
print(avg_income_notattrited)
if avg_income['Yes'] < avg_income['No']:
    print("Conclusion: Employees with lower average income have higher attrition.")
else:
    print("Conclusion: Higher income does not appear to reduce attrition.")
# Out:
# ('avg income attrited:', 4787.0928270042195)
# ('abg_income of not atrraited is:', 6832.739659367397)
# Conclusion: Employees with lower average income have higher attrition.

# %%
# Which income group has the highest attrition?
incomegroup_wise_attration=pd.crosstab(df['Income Group'],df['Attrition'],normalize='index')*100
print(incomegroup_wise_attration)
print("///////////////////////incomegroupattratied/////////////////////////////")
print(((incomegroup_wise_attration['Yes']).sort_values(ascending=False)).head(1))
# Out:
# Attrition              No        Yes
# Income Group
# Extremely High  96.240602   3.759398
# High            88.000000  12.000000
# Low             71.392405  28.607595
# Medium          87.283237  12.716763
# Very High       86.486486  13.513514
# ///////////////////////incomegroupattratied/////////////////////////////
# Income Group
# Low    28.607595
# Name: Yes, dtype: float64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Age Group',
#        'Income Group', 'Experience_Group'],
#       dtype='object')

# %%
# Which job role has the highest average income?
print(df.groupby("JobRole")['MonthlyIncome'].mean().sort_values(ascending=False).head(1))
# Out:
# JobRole
# Manager    17181.676471
# Name: MonthlyIncome, dtype: float64

# %%
# Which department has the highest average income?
print(df.groupby('Department')['MonthlyIncome'].mean().sort_values(ascending=False).head(1))
# Out:
# Department
# Sales    6959.172646
# Name: MonthlyIncome, dtype: float64

# %%
# What is the relationship between age and monthly income?
correltion=df['Age'].corr(df['MonthlyIncome'])
print(correltion)
# Out:
# 0.4978545669265805

# %% [markdown]
# visulastion

# %%
df.plot(
    x='Age',
    y='MonthlyIncome',
    kind='scatter',
    figsize=(7,5),
    title='Age vs Monthly Income'
)

plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Age Group',
#        'Income Group', 'Experience_Group'],
#       dtype='object')

# %%
# What is the relationship between job level and monthly income?
job_monthlyincomerltion=df.groupby('JobLevel')['MonthlyIncome'].mean()
print(job_monthlyincomerltion)
# Out:
# JobLevel
# 1     2786.915285
# 2     5502.277154
# 3     9817.252294
# 4    15503.783019
# 5    19191.826087
# Name: MonthlyIncome, dtype: float64

# %%
# Which job role has the highest salary variation?
salryvarition=df.groupby("JobRole")['MonthlyIncome'].std().sort_values(ascending=False).head(1)
print(salryvarition)
# Out:
# JobRole
# Research Director    2827.621369
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
#  **Job** & Experience Analysis

# %%
# What is the average total working experience?
avg_wroking_experince=df['TotalWorkingYears'].mean()
print("avg_working_experinceis:",avg_wroking_experince)
# Out:
# avg_working_experinceis: 11.279591836734694

# %%
#  What is the average number of years employees have worked at the company?\
avg_year_at_work=df['YearsAtCompany'].mean()
print(avg_year_at_work)
# Out:
# 7.0081632653061225

# %%
# Which job role has the highest average experience?
jobrole_avgexp = df.groupby('JobRole')['TotalWorkingYears'].mean()

print({
    'Job Role': jobrole_avgexp.idxmax(),
    'Experience': round(jobrole_avgexp.max(), 2)
})
# Out:
# {'Job Role': 'Manager', 'Experience': 24.55}

# %%
# Which department has the highest average experience?
dept_by_experince=df.groupby('Department')['TotalWorkingYears'].mean().sort_values(ascending=False)
print({
    'department':dept_by_experince.idxmax(),
    'Experience':dept_by_experince.max()})
# Out:
# {'department': 'Human Resources', 'Experience': 11.555555555555555}

# %%
# Does total working experience affect attrition?
# attrition_affect=df.groupby('Attrition')['TotalWorkingYears']
# print(attrition_affect)
attrition_affect=pd.crosstab(df['Attrition'],df['TotalWorkingYears'],normalize='index')*100
print(attrition_affect)
print(attrition_affect.loc['Yes'])

# %%
# Does years at the company affect attrition?
company_years_attrition = df.groupby('Attrition')['YearsAtCompany'].mean()
print(company_years_attrition.round(2))

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Age Group',
#        'Income Group', 'Experience_Group'],
#       dtype='object')

# %%
# Does years in the current role affect attrition?
years_at_jobrole=df.groupby('Attrition')['YearsInCurrentRole'].mean()
print(years_at_jobrole)
print(years_at_jobrole.round(2).to_dict())
# Out:
# Attrition
# No     4.484185
# Yes    2.902954
# Name: YearsInCurrentRole, dtype: float64
# {'No': 4.48, 'Yes': 2.9}

# %%
# Does years since the last promotion affect attrition?
last_promotion_affect_attrition=df.groupby('Attrition')['YearsSinceLastPromotion'].mean()
last_promotion_affect_attrition
print(last_promotion_affect_attrition.round(2).to_dict())
# Out:
# {'No': 2.23, 'Yes': 1.95}

# %%
# Does years with the current manager affect attrition?
years_with_current_manager__attrition=df.groupby("Attrition")['YearsWithCurrManager'].mean()
print(years_with_current_manager__attrition)
print(years_with_current_manager__attrition.round(2).to_dict())
# Out:
# Attrition
# No     4.367397
# Yes    2.852321
# Name: YearsWithCurrManager, dtype: float64
# {'No': 4.37, 'Yes': 2.85}

# %%
# Which experience group has the highest attrition?
experience_group_attrition = pd.crosstab(
    df['Experience_Group'],
    df['Attrition'],
    normalize='index'
) * 100

print(experience_group_attrition)

print({
    'Experience Group': experience_group_attrition['Yes'].idxmax(),
    'Attrition Rate': round(experience_group_attrition['Yes'].max(), 2)
})
# Out:
# Attrition                No        Yes
# Experience_Group
# 0-2 Years         56.097561  43.902439
# 11-20 Years       88.529412  11.470588
# 20+ Years         92.270531   7.729469
# 3-5 Years         80.829016  19.170984
# 6-10 Years        85.008237  14.991763
# {'Experience Group': '0-2 Years', 'Attrition Rate': 43.9}

# %%
# Which job level has the highest attrition?
joblevelattrition=pd.crosstab( df['JobLevel'],
                              df['Attrition'],
                              normalize='index'
)*100
print(joblevelattrition)
print({
    'JOB-LEVEL':joblevelattrition['Yes'].idxmax(),
    'Attrition-Rate':round(joblevelattrition['Yes'].max())
})
# Out:
# Attrition         No        Yes
# JobLevel
# 1          73.664825  26.335175
# 2          90.262172   9.737828
# 3          85.321101  14.678899
# 4          95.283019   4.716981
# 5          92.753623   7.246377
# {'JOB-LEVEL': np.int64(1), 'Attrition-Rate': 26}

# %%
# Which job level has the lowest attrition?
joblevelattrition=pd.crosstab( df['JobLevel'],
                              df['Attrition'],
                              normalize='index'
)*100
print(joblevelattrition)
print({
    'JOB-LEVEL':joblevelattrition['Yes'].idxmin(),
    'Attrition-Rate':round(joblevelattrition['Yes'].min())
})
# Out:
# Attrition         No        Yes
# JobLevel
# 1          73.664825  26.335175
# 2          90.262172   9.737828
# 3          85.321101  14.678899
# 4          95.283019   4.716981
# 5          92.753623   7.246377
# {'JOB-LEVEL': np.int64(4), 'Attrition-Rate': 5}

# %%
# Does job involvement affect attrition?
involvement_attrition = pd.crosstab(
    df['JobInvolvement'],
    df['Attrition'],
    normalize='index'
) * 100

print(involvement_attrition.round(2))
# Out:
# Attrition          No    Yes
# JobInvolvement
# 1               66.27  33.73
# 2               81.07  18.93
# 3               85.60  14.40
# 4               90.97   9.03

# %%
# Which job role has the highest job involvement?
involvement_attrition_highest = pd.crosstab(
    df['JobInvolvement'],
    df['Attrition'],
    normalize='index'
) * 100
print({'involvement_attrition_highest':involvement_attrition_highest['Yes'].idxmax(),
       'rateof attration':involvement_attrition_highest['Yes'].max()})
# Out:
# {'involvement_attrition_highest': np.int64(1), 'rateof attration': 33.734939759036145}

# %%
# Which department has the highest average job involvement?
department_involvement = (
    df.groupby('Department')['JobInvolvement']
    .mean()
    .sort_values(ascending=False)
)
department_involvement
department_involvement.head(1)
# Out:
# Department
# Human Resources    2.746032
# Name: JobInvolvement, dtype: float64

# %% [markdown]
#
#                                                           Satisfaction **Analysis**

# %%
# What is the distribution of job satisfaction?
job_satisfaction =df['JobSatisfaction'].value_counts().sort_index()
job_satisfaction
# Out:
# JobSatisfaction
# 1    289
# 2    280
# 3    442
# 4    459
# Name: count, dtype: int64

# %%
# Does job satisfaction affect attrition?
job_satisfaction_attrition =pd.crosstab(
    df['JobSatisfaction'],   df['Attrition'],
    normalize='index'
  )*100
print(job_satisfaction_attrition)
# Out:
# Attrition               No        Yes
# JobSatisfaction
# 1                77.162630  22.837370
# 2                83.571429  16.428571
# 3                83.484163  16.515837
# 4                88.671024  11.328976

# %%
# Which job satisfaction level has the highest attrition?
job_satisfaction_attrition =pd.crosstab(
    df['JobSatisfaction'],   df['Attrition'],
    normalize='index'
  )*100
print((job_satisfaction_attrition['Yes']).sort_values(ascending=False))
print({'Job Satisfaction': job_satisfaction_attrition['Yes'].idxmax(),
    'Attrition Rate': round(job_satisfaction_attrition['Yes'].max(), 2)})
# Out:
# JobSatisfaction
# 1    22.837370
# 3    16.515837
# 2    16.428571
# 4    11.328976
# Name: Yes, dtype: float64
# {'Job Satisfaction': np.int64(1), 'Attrition Rate': 22.84}

# %%
# Which job satisfaction level has the highest attrition?
job_satisfaction_attrition = pd.crosstab(
    df['JobSatisfaction'],
    df['Attrition'],
    normalize='index'
) * 100
print({
    'Job Satisfaction': job_satisfaction_attrition['Yes'].idxmax(),
    'Attrition Rate': round(job_satisfaction_attrition['Yes'].max(), 2)
})
# Out:
# {'Job Satisfaction': np.int64(1), 'Attrition Rate': 22.84}

# %%
# Which environment satisfaction level has the highest attrition?
environment_attrition = pd.crosstab(
    df['EnvironmentSatisfaction'],
    df['Attrition'],
    normalize='index'
) * 100
print(environment_attrition.round(2))
print({'environment satisfaction':environment_attrition['Yes'].idxmax(),
       'Attrition Rate':environment_attrition['Yes'].max()})
# Out:
# Attrition                   No    Yes
# EnvironmentSatisfaction
# 1                        74.65  25.35
# 2                        85.02  14.98
# 3                        86.31  13.69
# 4                        86.55  13.45
# {'environment satisfaction': np.int64(1), 'Attrition Rate': 25.352112676056336}

# %%
# Does relationship satisfaction affect attrition?
relationship_attrition = pd.crosstab(
    df['RelationshipSatisfaction'],
    df['Attrition'],
    normalize='index'
) * 100

print(relationship_attrition.round(2))
# Out:
# Attrition                    No    Yes
# RelationshipSatisfaction
# 1                         79.35  20.65
# 2                         85.15  14.85
# 3                         84.53  15.47
# 4                         85.19  14.81

# %%
# Does work-life balance affect attrition?
worklife_attrition = pd.crosstab(
    df['WorkLifeBalance'],
    df['Attrition'],
    normalize='index'
) * 100

print(worklife_attrition.round(2))
# Out:
# Attrition           No    Yes
# WorkLifeBalance
# 1                68.75  31.25
# 2                83.14  16.86
# 3                85.78  14.22
# 4                82.35  17.65

# %%
# Which work-life balance level has the highest attrition?
print("Highest Attrition Work-Life Balance Level:",
      worklife_attrition['Yes'].idxmax())
# Out:
# Highest Attrition Work-Life Balance Level: 1

# %%
 # Does job involvement affect attrition?
job_involvement_attrition = pd.crosstab(
    df['JobInvolvement'],
    df['Attrition'],
    normalize='index'
) * 100

print(job_involvement_attrition.round(2))
# Out:
# Attrition          No    Yes
# JobInvolvement
# 1               66.27  33.73
# 2               81.07  18.93
# 3               85.60  14.40
# 4               90.97   9.03

# %%
# Which department has the lowest average job satisfaction?
department_satisfaction = (
    df.groupby('Department')['JobSatisfaction']
    .mean()
    .sort_values()
)

print(department_satisfaction.round(2))

print("Lowest Average Job Satisfaction Department:",
      department_satisfaction.idxmin())
# Out:
# Department
# Human Resources           2.60
# Research & Development    2.73
# Sales                     2.75
# Name: JobSatisfaction, dtype: float64
# Lowest Average Job Satisfaction Department: Human Resources

# %% [markdown]
#                                                  Advanced Analysis

# %%
# Which department + job role combination has the highest attrition?
dept_role_attrition = (
    df.groupby(['Department', 'JobRole'])['Attrition']
    .apply(lambda x: (x == 'Yes').mean() * 100)
    .sort_values(ascending=False)
)

print(dept_role_attrition.round(2))
print("Highest Attrition Combination:",
      dept_role_attrition.idxmax())
# Out:
# Department              JobRole
# Sales                   Sales Representative         39.76
# Research & Development  Laboratory Technician        23.94
# Human Resources         Human Resources              23.08
# Sales                   Sales Executive              17.48
# Research & Development  Research Scientist           16.10
#                         Manufacturing Director        6.90
#                         Healthcare Representative     6.87
#                         Manager                       5.56
# Sales                   Manager                       5.41
# Research & Development  Research Director             2.50
# Human Resources         Manager                       0.00
# Name: Attrition, dtype: float64
# Highest Attrition Combination: ('Sales', 'Sales Representative')

# %%
# Which age group + overtime combination has the highest attrition?
age_overtime_attrition = (
    df.groupby(['Age Group', 'OverTime'])['Attrition']
    .apply(lambda x: (x == 'Yes').mean() * 100)
    .sort_values(ascending=False)
)

print(age_overtime_attrition.round(2))
print("Highest Attrition Combination:",
      age_overtime_attrition.idxmax())
# Out:
# Age Group  OverTime
# Under 25   Yes         64.10
# 25-35      Yes         38.99
# 55+        Yes         23.53
# Under 25   No          22.62
# 46-55      Yes         19.70
# 36-45      Yes         17.04
# 55+        No          13.33
# 25-35      No          12.08
# 46-55      No           8.12
# 36-45      No           6.01
# Name: Attrition, dtype: float64
# Highest Attrition Combination: ('Under 25', 'Yes')

# %%
# Which income group + overtime combination has the highest attrition?
income_overtime_attrition = (
    df.groupby(['Income Group', 'OverTime'])['Attrition']
    .apply(lambda x: (x == 'Yes').mean() * 100)
    .sort_values(ascending=False)
)

print(income_overtime_attrition.round(2))
print("Highest Attrition Combination:",
      income_overtime_attrition.idxmax())
# Out:
# Income Group    OverTime
# Low             Yes         56.14
# Medium          Yes         24.11
# High            Yes         22.37
# Low             No          17.44
# Very High       Yes         17.31
#                 No          11.46
# Extremely High  Yes          9.09
# Medium          No           8.47
# High            No           8.04
# Extremely High  No           2.00
# Name: Attrition, dtype: float64
# Highest Attrition Combination: ('Low', 'Yes')

# %%
# Which job role + overtime combination has the highest attrition?
income_overtime_attrition = (
    df.groupby(['Income Group', 'OverTime'])['Attrition']
    .apply(lambda x: (x == 'Yes').mean() * 100)
    .sort_values(ascending=False)
)

print(income_overtime_attrition.round(2))
print("Highest Attrition Combination:",
      income_overtime_attrition.idxmax())
# Out:
# Income Group    OverTime
# Low             Yes         56.14
# Medium          Yes         24.11
# High            Yes         22.37
# Low             No          17.44
# Very High       Yes         17.31
#                 No          11.46
# Extremely High  Yes          9.09
# Medium          No           8.47
# High            No           8.04
# Extremely High  No           2.00
# Name: Attrition, dtype: float64
# Highest Attrition Combination: ('Low', 'Yes')

# %%
# Employee type most likely to leave
employee_risk = (
    df.groupby(['JobRole', 'OverTime'])['Attrition']
    .apply(lambda x: (x == 'Yes').mean() * 100)
    .sort_values(ascending=False)
)
print(employee_risk.head(10).round(2))
employee_risk = (
    df.groupby(['Age Group', 'Income Group', 'OverTime'])['Attrition']
    .apply(lambda x: (x == 'Yes').mean() * 100)
    .sort_values(ascending=False)
)

print(employee_risk.head(10).round(2))
# Out:
# JobRole                OverTime
# Sales Representative   Yes         66.67
# Laboratory Technician  Yes         50.00
# Human Resources        Yes         38.46
# Research Scientist     Yes         34.02
# Sales Executive        Yes         32.98
# Sales Representative   No          28.81
# Human Resources        No          17.95
# Laboratory Technician  No          15.74
# Manager                Yes         14.81
# Sales Executive        No          11.21
# Name: Attrition, dtype: float64
# Age Group  Income Group  OverTime
# Under 25   Low           Yes         73.08
# 46-55      Low           Yes         60.00
# 25-35      Low           Yes         59.26
# 55+        Low           Yes         50.00
# Under 25   Medium        Yes         46.15
# 46-55      High          Yes         42.86
# 55+        Low           No          37.50
# 36-45      Low           Yes         33.33
# 25-35      Medium        Yes         30.65
# Under 25   Low           No          28.85
# ...

# %%
# Employee type most likely to stay
employee_stay = (
    df.groupby(['JobRole', 'OverTime'])['Attrition']
    .apply(lambda x: (x == 'No').mean() * 100)
    .sort_values(ascending=False)
)
print(employee_stay.head(10).round(2))
# Out:
# JobRole                    OverTime
# Manager                    No          98.67
# Research Director          No          98.25
#                            Yes         95.65
# Healthcare Representative  Yes         94.59
# Manufacturing Director     No          94.34
# Research Scientist         No          92.82
# Healthcare Representative  No          92.55
# Manufacturing Director     Yes         89.74
# Sales Executive            No          88.79
# Manager                    Yes         85.19
# Name: Attrition, dtype: float64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Age Group',
#        'Income Group', 'Experience_Group'],
#       dtype='object')

# %%
# Create Attrition Flag

df['Attrition_Flag'] = df['Attrition'].map({
    'Yes': 1,
    'No': 0
})

print(df[['Attrition', 'Attrition_Flag']].head())
# Out:
#   Attrition  Attrition_Flag
# 0       Yes               1
# 1        No               0
# 2       Yes               1
# 3        No               0
# 4        No               0

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %% [markdown]
# visulas

# %%
# Overall Attrition
attrition_counts = df['Attrition'].value_counts()

attrition_counts.plot(
    kind='bar',
    figsize=(6,4),
    title='Employee Attrition'
)
plt.xlabel('Attrition')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# Attrition by Department

# %%
dept_attrition = pd.crosstab(
    df['Department'],
    df['Attrition'],
    normalize='index'
) * 100

dept_attrition['Yes'].plot(
    kind='bar',
    figsize=(7,4),
    title='Attrition Rate by Department'
)
plt.xlabel('Department')
plt.ylabel('Attrition Rate (%)')
plt.show()

# %% [markdown]
# Attrition by Job Role

# %%
role_attrition = pd.crosstab(
    df['JobRole'],
    df['Attrition'],
    normalize='index'
) * 100

role_attrition['Yes'].sort_values().plot(
    kind='barh',
    figsize=(8,5),
    title='Attrition Rate by Job Role'
)
plt.xlabel('Attrition Rate (%)')
plt.ylabel('Job Role')
plt.show()

# %% [markdown]
# Attrition by Overtime

# %%
overtime_attrition = pd.crosstab(
    df['OverTime'],
    df['Attrition'],
    normalize='index'
) * 100

overtime_attrition['Yes'].plot(
    kind='bar',
    figsize=(6,4),
    title='Attrition Rate by Overtime'
)
plt.xlabel('Overtime')
plt.ylabel('Attrition Rate (%)')
plt.show()

# %% [markdown]
# Attrition by Age Group

# %%
age_attrition = pd.crosstab(
    df['Age Group'],
    df['Attrition'],
    normalize='index'
) * 100

age_attrition['Yes'].plot(
    kind='bar',
    figsize=(7,4),
    title='Attrition Rate by Age Group'
)
plt.xlabel('Age Group')
plt.ylabel('Attrition Rate (%)')
plt.show()

# %% [markdown]
# Attrition by Income Group

# %%
income_attrition = pd.crosstab(
    df['Income Group'],
    df['Attrition'],
    normalize='index'
) * 100

income_attrition['Yes'].plot(
    kind='bar',
    figsize=(7,4),
    title='Attrition Rate by Income Group'
)
plt.xlabel('Income Group')
plt.ylabel('Attrition Rate (%)')
plt.show()

# %% [markdown]
# Age vs Monthly Income

# %%
df.plot(
    x='Age',
    y='MonthlyIncome',
    kind='scatter',
    figsize=(7,5),
    title='Age vs Monthly Income'
)

plt.xlabel('Age')
plt.ylabel('Monthly Income')
plt.show()

# %% [markdown]
#  Work-Life Balance vs Attrition

# %%
worklife_attrition = pd.crosstab(
    df['WorkLifeBalance'],
    df['Attrition'],
    normalize='index'
) * 100

worklife_attrition['Yes'].plot(
    kind='bar',
    figsize=(7,4),
    title='Attrition Rate by Work-Life Balance'
)
plt.xlabel('Work-Life Balance Level')
plt.ylabel('Attrition Rate (%)')
plt.show()
